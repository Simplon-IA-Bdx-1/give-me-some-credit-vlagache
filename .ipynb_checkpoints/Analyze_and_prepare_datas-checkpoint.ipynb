# %%
# %store
# Out:
# Stored variables and their in-db values:
# df                         ->         RevolvingUtilizationOfUnsecuredLines  age
# model                      -> XGBClassifier(base_score=0.5, booster='gbtree', co
# train_prepared             ->         RevolvingUtilizationOfUnsecuredLines  age

# %%
# %store -r 
data = df
print(data.shape)
# Out:
# (150000, 11)

# %% [markdown]
# ### Informations sur le dataset

# %%
from pandas import set_option

# data.head(20)
# data.dtypes

set_option('display.width', 100)
set_option('precision', 3)
data.describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines         age  NumberOfTime30-59DaysPastDueNotWorse  \
# count                            150000.000  150000.000                            150000.000
# mean                                  6.048      52.295                                 0.421
# std                                 249.755      14.772                                 4.193
# min                                   0.000       0.000                                 0.000
# 25%                                   0.030      41.000                                 0.000
# 50%                                   0.154      52.000                                 0.000
# 75%                                   0.559      63.000                                 0.000
# max                               50708.000     109.000                                98.000
#
#         DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# count  150000.000      1.203e+05                       150000.000               150000.000
# mean      353.005      6.670e+03                            8.453                    0.266
# std      2037.819      1.438e+04                            5.146                    4.169
# min         0.000      0.000e+00                            0.000                    0.000
# 25%         0.175      3.400e+03                            5.000                    0.000
# 50%         0.367      5.400e+03                            8.000                    0.000
# 75%         0.868      8.249e+03                           11.000                    0.000
# max    329664.000      3.009e+06                           58.000                   98.000
#
#        NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  NumberOfDependents  \
# count                    150000.000                            150000.000          146076.000
# mean                          1.018                                 0.240               0.757
# std                           1.130                                 4.155               1.115
# min                           0.000                                 0.000               0.000
# 25%                           0.000                                 0.000               0.000
# 50%                           1.000                                 0.000               0.000
# 75%                           2.000                                 0.000               1.000
# max                          54.000                                98.000              20.000
#
#        SeriousDlqin2yrs
# count        150000.000
# mean              0.067
# std               0.250
# min               0.000
# 25%               0.000
# 50%               0.000
# 75%               0.000
# max               1.000

# %% [markdown]
# ### Distribution des outputs

# %%
class_counts = data.groupby('SeriousDlqin2yrs').size()
print(class_counts)
# Out:
# SeriousDlqin2yrs
# 0    139974
# 1     10026
# dtype: int64

# %% [markdown]
# ### Corrélation de Pearson

# %%
# 1 ou -1 Forte correlation positive ou négative , 0 pas de corrélation du tout 
set_option('display.width', 100)
set_option('precision', 3)
correlations = data.corr(method='pearson')
print(correlations)
# Out:
#                                       RevolvingUtilizationOfUnsecuredLines    age  \
# RevolvingUtilizationOfUnsecuredLines                                 1.000 -0.006
# age                                                                 -0.006  1.000
# NumberOfTime30-59DaysPastDueNotWorse                                -0.001 -0.063
# DebtRatio                                                            0.004  0.024
# MonthlyIncome                                                        0.007  0.038
# NumberOfOpenCreditLinesAndLoans                                     -0.011  0.148
# NumberOfTimes90DaysLate                                             -0.001 -0.061
# NumberRealEstateLoansOrLines                                         0.006  0.033
# NumberOfTime60-89DaysPastDueNotWorse                                -0.001 -0.057
# NumberOfDependents                                                   0.002 -0.213
# SeriousDlqin2yrs                                                    -0.002 -0.115
#
#                                       NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  \
# RevolvingUtilizationOfUnsecuredLines                                -0.001      0.004
# age                                                                 -0.063      0.024
# NumberOfTime30-59DaysPastDueNotWorse                                 1.000     -0.007
# DebtRatio                                                           -0.007      1.000
# MonthlyIncome                                                       -0.010     -0.029
# NumberOfOpenCreditLinesAndLoans                                     -0.055      0.050
# NumberOfTimes90DaysLate                                              0.984     -0.008
# NumberRealEstateLoansOrLines                                        -0.031      0.120
# NumberOfTime60-89DaysPastDueNotWorse                                 0.987     -0.008
# NumberOfDependents                                                  -0.003     -0.041
# SeriousDlqin2yrs                                                     0.126     -0.008
#
#                                       MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# RevolvingUtilizationOfUnsecuredLines          0.007                           -0.011
# age                                           0.038                            0.148
# NumberOfTime30-59DaysPastDueNotWorse         -0.010                           -0.055
# DebtRatio                                    -0.029                            0.050
# MonthlyIncome                                 1.000                            0.091
# NumberOfOpenCreditLinesAndLoans               0.091                            1.000
# NumberOfTimes90DaysLate                      -0.013                           -0.080
# NumberRealEstateLoansOrLines                  0.125                            0.434
# NumberOfTime60-89DaysPastDueNotWorse         -0.011                           -0.071
# NumberOfDependents                            0.063                            0.065
# SeriousDlqin2yrs                             -0.020                           -0.030
#
#                                       NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# RevolvingUtilizationOfUnsecuredLines                   -0.001                         0.006
# age                                                    -0.061                         0.033
# NumberOfTime30-59DaysPastDueNotWorse                    0.984                        -0.031
# DebtRatio                                              -0.008                         0.120
# MonthlyIncome                                          -0.013                         0.125
# NumberOfOpenCreditLinesAndLoans                        -0.080                         0.434
# NumberOfTimes90DaysLate                                 1.000                        -0.045
# NumberRealEstateLoansOrLines                           -0.045                         1.000
# NumberOfTime60-89DaysPastDueNotWorse                    0.993                        -0.040
# NumberOfDependents                                     -0.010                         0.125
# SeriousDlqin2yrs                                        0.117                        -0.007
#
#                                       NumberOfTime60-89DaysPastDueNotWorse  NumberOfDependents  \
# RevolvingUtilizationOfUnsecuredLines                                -0.001               0.002
# age                                                                 -0.057              -0.213
# NumberOfTime30-59DaysPastDueNotWorse                                 0.987              -0.003
# DebtRatio                                                           -0.008              -0.041
# MonthlyIncome                                                       -0.011               0.063
# NumberOfOpenCreditLinesAndLoans                                     -0.071               0.065
# NumberOfTimes90DaysLate                                              0.993              -0.010
# NumberRealEstateLoansOrLines                                        -0.040               0.125
# NumberOfTime60-89DaysPastDueNotWorse                                 1.000              -0.011
# NumberOfDependents                                                  -0.011               1.000
# SeriousDlqin2yrs                                                     0.102               0.046
#
#                                       SeriousDlqin2yrs
# RevolvingUtilizationOfUnsecuredLines            -0.002
# age                                             -0.115
# NumberOfTime30-59DaysPastDueNotWorse             0.126
# DebtRatio                                       -0.008
# MonthlyIncome                                   -0.020
# NumberOfOpenCreditLinesAndLoans                 -0.030
# NumberOfTimes90DaysLate                          0.117
# NumberRealEstateLoansOrLines                    -0.007
# NumberOfTime60-89DaysPastDueNotWorse             0.102
# NumberOfDependents                               0.046
# SeriousDlqin2yrs                                 1.000

# %%
skew = data.skew()
print(skew)
# Out:
# RevolvingUtilizationOfUnsecuredLines     97.632
# age                                       0.189
# NumberOfTime30-59DaysPastDueNotWorse     22.597
# DebtRatio                                95.158
# MonthlyIncome                           114.040
# NumberOfOpenCreditLinesAndLoans           1.215
# NumberOfTimes90DaysLate                  23.087
# NumberRealEstateLoansOrLines              3.482
# NumberOfTime60-89DaysPastDueNotWorse     23.332
# NumberOfDependents                        1.588
# SeriousDlqin2yrs                          3.469
# dtype: float64

# %% [markdown]
# ### Distribution de chaque feature

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = [20 , 15]
data.hist()
plt.show()

# %% [markdown]
# #### Density Plots

# %%
data.plot(kind='density', subplots=True, layout=(4,3),  sharex=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Box & Whisker Plots

# %%
data.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
